# %% [markdown]
# Os maiores artilhieros brasileiros da copa Libertadores da América
# Dados de maio de 2023

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
artilhariabr = {
    'Gabigol': 31,
    'Luizão': 29,
    'Palhinha': 25,
    'Fred': 25,
    'Bruno H': 22,
    'Célio': 22,
    'Rony': 21,
    'Jairzinho': 21 
}

# %%
serie1 = pd.Series(artilhariabr)
serie1
# Out:
# Gabigol      31
# Luizão       29
# Palhinha     25
# Fred         25
# Bruno H      22
# Célio        22
# Rony         21
# Jairzinho    21
# dtype: int64

# %%
serie1.plot()
# Out:
# <Axes: >

# %% [markdown]
# O gráfico mostra a classificação dos artilheiros brasileiros na libertadores em termos de número de gols marcados. Gabigol lidera a lista. Isso pode ser útil para entender o desempenho dos jogadores.
